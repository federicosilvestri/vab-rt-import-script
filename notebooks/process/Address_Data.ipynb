# %%
from vab_rt_import.source import get_data
df = get_data()

# %%
from vab_rt_import.process.address import process

# %%
df = process(df)

# %%
df
# Out:
#      address_country address_province   address_comune address_cap  \
# 0             Italia          Firenze        Calenzano       50041
# 1             Italia          Pistoia         Quarrata       51038
# 2             Italia          Viterbo            Onano         NaN
# 3             Italia    Massa-Carrara          Carrara       54031
# 4             Italia           Torino        Montanaro       52044
# ...              ...              ...              ...         ...
# 9326          Italia          Firenze           Empoli         NaN
# 9327          Italia         Grosseto        Follonica       58022
# 9328          Italia            Prato  Poggio a Caiano         NaN
# 9329            Mali              NaN              NaN         NaN
# 9330          Italia          Firenze          Firenze         NaN
#
#          address_street address_civico address_phone_home  \
# 0             di leccio             37                NaN
# ...

# %%
df[df['address_comune'] == 'Massa e Cozzile']
# Out:
#      address_country address_province   address_comune address_cap  \
# 511           Italia          Pistoia  Massa e Cozzile       51010
# 1691          Italia          Pistoia  Massa e Cozzile       51010
# 1952          Italia          Pistoia  Massa e Cozzile       51010
# 1953          Italia          Pistoia  Massa e Cozzile       51010
# 2363          Italia          Pistoia  Massa e Cozzile       51010
# ...              ...              ...              ...         ...
# 8718          Italia          Pistoia  Massa e Cozzile         NaN
# 8745          Italia          Pistoia  Massa e Cozzile         NaN
# 8942          Italia          Pistoia  Massa e Cozzile         NaN
# 9239          Italia          Pistoia  Massa e Cozzile         NaN
# 9240          Italia          Pistoia  Massa e Cozzile         NaN
#
#               address_street address_civico address_phone_home  \
# 511         via vacchereccia             15          057271723
# ...
