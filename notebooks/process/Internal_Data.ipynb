# %%
from vab_rt_import.source import get_data
df = get_data()

# %%
list(df.columns)
# Out:
# ['id',
#  'cognome_socio',
#  'nome_socio',
#  'num_tessera',
#  'num_tessera_associazione',
#  'lettera_id_regione_vab',
#  'flag_socio',
#  'flag_volontario',
#  'socio_inattivo',
#  'qualifica_socio',
#  'data_disattivazione_socio',
#  'note_disattivazione_socio',
#  'carica_socio',
#  'data_iscriz',
#  'data_registr_libro_soci',
#  'rinnovo_tessera',
#  'nato_a',
#  'nato_il',
#  'cod_fisc',
#  'sesso_socio',
#  'id_sesso_socio',
#  'residente_a',
#  'via',
#  'num_civico',
#  'cap',
#  'provincia',
#  'tipo_doc_identita_socio',
#  'numero_doc_identita_socio',
#  'scadenza_doc_identita_socio',
#  'doc_identita_socio_rilasc_da',
#  'tel_abit',
#  'tel_cellulare',
#  'tel_altro',
#  'email',
#  'flag_attivita_antincendio',
#  'flag_attivita_protciv',
#  'flag_attivita_ecologiche',
#  'flag_attivita_logistiche',
#  'flag_attivita_altro',
#  'nome_azienda',
#  'indirizzo_azienda',
#  'cap_azienda',
#  'comune_azienda',
#  'prov_azienda',
#  'tel_azienda',
#  'fax_azienda',
# ...

# %%
columns = ['id', 'num_tessera', 'num_tessera_associazione', "id_sezione_vab", 'lettera_id_regione_vab', 'flag_socio', 'flag_volontario', 'socio_inattivo', 'carica_socio', 'data_iscriz', 'data_registr_libro_soci', "badge", "badge2"]
df[columns]
# Out:
#         id num_tessera  num_tessera_associazione lettera_id_regione_vab  \
# 0        5        8248                         0                      T
# 1        7        5677                         0                      T
# 2        8        6210                         0                      T
# 3       11        7614                         0                      T
# 4       13        7389                         0                      T
# ...    ...         ...                       ...                    ...
# 9326  9698                                     0                      T
# 9327  9699                                     0                      T
# 9328  9700                                     0                      T
# 9329  9701                                     0                      T
# 9330  9702                                     0                      T
#
#      flag_socio flag_volontario  socio_inattivo  carica_socio data_iscriz  \
# ...

# %%
df['rinnovo_tessera'].value_counts()
# Out:
# rinnovo_tessera
# 0000-00-00    9327
# 1900-12-31       4
# Name: count, dtype: int64

# %% [markdown]
# 'rinnovo_tessera' non serve a nulla

# %%
df['lettera_id_regione_vab'].value_counts()
# Out:
# lettera_id_regione_vab
# T    9080
# S     131
# A      95
#        19
# L       2
# P       2
# I       1
# M       1
# Name: count, dtype: int64

# %%
df["id_sezione_vab"].value_counts()
# Out:
# id_sezione_vab
# 16     578
# 17     543
# 37     378
# 42     355
# 24     332
#       ...
# 97       1
# 101      1
# 127      1
# 170      1
# 145      1
# Name: count, Length: 79, dtype: int64
